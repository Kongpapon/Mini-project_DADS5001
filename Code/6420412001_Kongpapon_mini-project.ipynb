# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
path = ('C:\\Users\\Sense\\Desktop\\data project\\2563.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['ม.ค.2563(P)', 'ก.พ.2563(P)', 'มี.ค.2563(P)', 'เม.ย.2563(P)', 'พ.ค.2563(P)', 'มิ.ย.2563(P)', 'ก.ค.2563(P)', 'ส.ค.2563(P)', 'ก.ย.2563(P)', 'ต.ค.2563(P)', 'พ.ย.2563(P)', 'ธ.ค.2563(P)', 'ยอดสะสมม.ค.-ธ.ค.2563']

# %%
# 2563
df1 = xl.parse('ม.ค.2563(P)')
df2 = xl.parse('ก.พ.2563(P)')
df3 = xl.parse('มี.ค.2563(P)')
df4 = xl.parse('เม.ย.2563(P)')
df5 = xl.parse('พ.ค.2563(P)')
df6 = xl.parse('มิ.ย.2563(P)')
df7 = xl.parse('ก.ค.2563(P)')
df8 = xl.parse('ส.ค.2563(P)')
df9 = xl.parse('ก.ย.2563(P)')
df10 = xl.parse('ต.ค.2563(P)')
df11 = xl.parse('พ.ย.2563(P)')
df12 = xl.parse('ธ.ค.2563(P)')
df25 = xl.parse('ยอดสะสมม.ค.-ธ.ค.2563')

# %%
path = ('C:\\Users\\Sense\\Desktop\\data project\\2564.xlsx')
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Out:
# ['ม.ค.2564(P)', 'ก.พ.2564(P)', 'มี.ค.2564(P)', 'เม.ย.2564(P)', 'พ.ค.2564(P)', 'มิ.ย.2564(P)', 'ก.ค.2564(P)', 'ส.ค.2564(P)', 'ก.ย.2564(P)', 'ต.ค.2564(P)', 'พ.ย.2564(P)', 'ธ.ค.2564(P)', 'ยอดสะสมม.ค.-ธ.ค.2564']

# %%
# 2564
df13 = xl.parse('ม.ค.2564(P)')
df14 = xl.parse('ก.พ.2564(P)')
df15 = xl.parse('มี.ค.2564(P)')
df16 = xl.parse('เม.ย.2564(P)')
df17 = xl.parse('พ.ค.2564(P)')
df18 = xl.parse('มิ.ย.2564(P)')
df19 = xl.parse('ก.ค.2564(P)')
df20 = xl.parse('ส.ค.2564(P)')
df21 = xl.parse('ก.ย.2564(P)')
df22 = xl.parse('ต.ค.2564(P)')
df23 = xl.parse('พ.ย.2564(P)')
df24 = xl.parse('ธ.ค.2564(P)')
df26 = xl.parse('ยอดสะสมม.ค.-ธ.ค.2564')

# %% [markdown]
# ปี 2563

# %%
df_1 = df1.loc[(df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคกลาง') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคใต้') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคเหนือ') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df1['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)','Unnamed: 20']]
df_2 = df2.loc[(df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคกลาง') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคตะวันตก') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคตะวันออก') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคใต้') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคเหนือ') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df2['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)','Unnamed: 20']]
df_3 = df3.loc[(df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคกลาง') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคใต้') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df3['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)','Unnamed: 20']]
df_4 = df4.loc[(df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคกลาง') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคตะวันตก') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคตะวันออก') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคใต้') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคเหนือ') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df4['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)','Unnamed: 20']]
df_5 = df5.loc[(df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคกลาง') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคใต้') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df5['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)','Unnamed: 20']]
df_6 = df6.loc[(df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคกลาง') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคตะวันตก') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคตะวันออก') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคใต้') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคเหนือ') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df6['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)','Unnamed: 20']]
df_7 = df7.loc[(df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคกลาง') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคใต้') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df7['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)','Unnamed: 20']]
df_8 = df8.loc[(df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคกลาง') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคใต้') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df8['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)','Unnamed: 20']]
df_9 = df9.loc[(df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคกลาง') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคตะวันตก') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคตะวันออก') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคใต้') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคเหนือ') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df9['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)','Unnamed: 20']]
df_10 = df10.loc[(df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคกลาง') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคใต้') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df10['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)','Unnamed: 20']]
df_11 = df11.loc[(df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคกลาง') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคตะวันตก') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคตะวันออก') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคใต้') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคเหนือ') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df11['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)','Unnamed: 20']]
df_12 = df12.loc[(df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคกลาง') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคใต้') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df12['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)','Unnamed: 20']]
df_25 = df25.loc[(df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคกลาง') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคใต้') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df25['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)','Unnamed: 20']]

# %%
df_1 = df_1.rename(columns={"รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)": "ภาค", "Unnamed: 20": "January"})
df_2 = df_2.rename(columns={"รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)": "ภาค", "Unnamed: 20": "February"})
df_3 = df_3.rename(columns={"รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "March"})
df_4 = df_4.rename(columns={"รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)": "ภาค", "Unnamed: 20": "April"})
df_5 = df_5.rename(columns={"รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "May"})
df_6 = df_6.rename(columns={"รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)": "ภาค", "Unnamed: 20": "June"})
df_7 = df_7.rename(columns={"รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "July"})
df_8 = df_8.rename(columns={"รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "August"})
df_9 = df_9.rename(columns={"รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)": "ภาค", "Unnamed: 20": "September"})
df_10 = df_10.rename(columns={"รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "October"})
df_11 = df_11.rename(columns={"รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)": "ภาค", "Unnamed: 20": "November"})
df_12 = df_12.rename(columns={"รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "December"})
df_25 = df_25.rename(columns={"ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)": "ภาค", "Unnamed: 20": "รายได้"})

# %%
df_25.iloc[0,0] = 'Bangkok'
df_25.iloc[1,0] = 'Central Region'
df_25.iloc[2,0] = 'Western Region'
df_25.iloc[3,0] = 'Eastern Region'
df_25.iloc[4,0] = 'South Region'
df_25.iloc[5,0] = 'North Region'
df_25.iloc[6,0] = 'Northeast'
df_25.iloc[7,0] = 'Thailand'

# %%
y_2563 = df_1.merge(df_2, how='inner').merge(df_3, how='inner').merge(df_4, how='inner').merge(df_5, how='inner').merge(df_6, how='inner').merge(df_7, how='inner').merge(df_8, how='inner').merge(df_9, how='inner').merge(df_10, how='inner').merge(df_11, how='inner').merge(df_12, how='inner')
y_2563
# Out:
#                      ภาค   January  February     March   April      May  \
# 0          กรุงเทพมหานคร  31137.65  18810.39   6403.18  434.06  1653.74
# 1                ภาคกลาง    3772.3   2418.54    673.84    1.64    13.63
# 2             ภาคตะวันตก   7814.02   5882.98    2552.4    2.43     75.8
# 3            ภาคตะวันออก   9400.96   6446.97   3776.46       0    61.66
# 4                 ภาคใต้  18268.15   14878.9    8542.8    6.12     3.42
# 5               ภาคเหนือ  14610.89  10578.07   5594.09    54.1   238.52
# 6  ภาคตะวันออกเฉียงเหนือ   8859.16   7023.87   1717.84    1.18    92.55
# 7             รวมทั้งหมด  93863.13  66039.72  29260.61  499.53  2139.32
#
#        June     July    August September   October  November  December
# 0   5189.09  8348.66  14263.35  14106.67   9467.42  11988.41  11958.58
# 1    497.18  1597.46   1683.32   1816.86   2638.93   3258.51   2883.07
# 2   2283.41  5173.71   4550.69   4351.14   6061.24   6652.78   5671.41
# ...

# %% [markdown]
# ปี 2564

# %%
df_13 = df13.loc[(df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคกลาง') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคใต้') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคเหนือ') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df13['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)','Unnamed: 20']]
df_14 = df14.loc[(df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคกลาง') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคตะวันตก') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคตะวันออก') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคใต้') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคเหนือ') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df14['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)','Unnamed: 20']]
df_15 = df15.loc[(df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคกลาง') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคใต้') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df15['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)','Unnamed: 20']]
df_16 = df16.loc[(df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคกลาง') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคตะวันตก') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคตะวันออก') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคใต้') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคเหนือ') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df16['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)','Unnamed: 20']]
df_17 = df17.loc[(df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคกลาง') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคใต้') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df17['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)','Unnamed: 20']]
df_18 = df18.loc[(df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคกลาง') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคตะวันตก') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคตะวันออก') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคใต้') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคเหนือ') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df18['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)','Unnamed: 20']]
df_19 = df19.loc[(df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคกลาง') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคใต้') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df19['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)','Unnamed: 20']]
df_20 = df20.loc[(df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคกลาง') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคใต้') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df20['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)','Unnamed: 20']]
df_21 = df21.loc[(df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคกลาง') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคตะวันตก') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคตะวันออก') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคใต้') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคเหนือ') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df21['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)','Unnamed: 20']]
df_22 = df22.loc[(df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคกลาง') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคใต้') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df22['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)','Unnamed: 20']]
df_23 = df23.loc[(df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคกลาง') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคตะวันตก') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคตะวันออก') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคใต้') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคเหนือ') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df23['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)','Unnamed: 20']]
df_24 = df24.loc[(df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคกลาง') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคใต้') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df24['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)','Unnamed: 20']]
df_26 = df26.loc[(df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'กรุงเทพมหานคร') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคกลาง') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคตะวันตก') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคตะวันออก') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคใต้') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคเหนือ') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df26['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)','Unnamed: 20']]

# %%
df_13 = df_13.rename(columns={"รายงานเบื้องต้นเดือนมกราคม ปี 2564(P)": "ภาค", "Unnamed: 20": "January"})
df_14 = df_14.rename(columns={"รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2564(P)": "ภาค", "Unnamed: 20": "February"})
df_15 = df_15.rename(columns={"รายงานเบื้องต้นเดือนมีนาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "March"})
df_16 = df_16.rename(columns={"รายงานเบื้องต้นเดือนเมษายน ปี 2564(P)": "ภาค", "Unnamed: 20": "April"})
df_17 = df_17.rename(columns={"รายงานเบื้องต้นเดือนพฤษภาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "May"})
df_18 = df_18.rename(columns={"รายงานเบื้องต้นเดือนมิถุนายน ปี 2564(P)": "ภาค", "Unnamed: 20": "June"})
df_19 = df_19.rename(columns={"รายงานเบื้องต้นเดือนกรกฎาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "July"})
df_20 = df_20.rename(columns={"รายงานเบื้องต้นเดือนสิงหาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "August"})
df_21 = df_21.rename(columns={"รายงานเบื้องต้นเดือนกันยายน ปี 2564(P)": "ภาค", "Unnamed: 20": "September"})
df_22 = df_22.rename(columns={"รายงานเบื้องต้นเดือนตุลาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "October"})
df_23 = df_23.rename(columns={"รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2564(P)": "ภาค", "Unnamed: 20": "November"})
df_24 = df_24.rename(columns={"รายงานเบื้องต้นเดือนธันวาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "December"})
df_26 = df_26.rename(columns={"รายงานเบื้องต้นเดือนมกราคม - ธันวาคม ปี 2564(P)": "ภาค", "Unnamed: 20": "รายได้"})

# %%
y_2564 = df_13.merge(df_14, how='inner').merge(df_15, how='inner').merge(df_16, how='inner').merge(df_17, how='inner').merge(df_18, how='inner').merge(df_19, how='inner').merge(df_19, how='inner').merge(df_20, how='inner').merge(df_21, how='inner').merge(df_22, how='inner').merge(df_23, how='inner').merge(df_24, how='inner')
y_2564
# Out:
#                      ภาค   January  February     March     April      May  \
# 0          กรุงเทพมหานคร   8447.45   9799.71   9845.58    6164.5  1068.55
# 1                ภาคกลาง   1073.39    1453.5    2040.9   1058.73   171.81
# 2             ภาคตะวันตก   2920.88   4393.14    5557.7   3416.72   459.34
# 3            ภาคตะวันออก    743.11   1665.76   2380.19   2817.04   426.81
# 4                 ภาคใต้   2965.96   3763.53   6186.27   6231.22   213.46
# 5               ภาคเหนือ   4114.65   5069.43   5639.92   6106.88  1038.33
# 6  ภาคตะวันออกเฉียงเหนือ   2612.74   3388.68   4242.97    1541.0   387.91
# 7             รวมทั้งหมด  22878.18  29533.75  35893.53  27336.09  3766.21
#
#       June     July   August September   October  November  December
# 0   743.11   429.87   519.84   1275.61   1493.63   2913.82   9845.11
# 1   153.56    60.45    58.37    229.75    745.94   1748.03   3032.82
# 2   438.48   185.36   128.37    852.46   2498.72   4468.84   6068.01
# ...

# %%
df_26.iloc[0,0] = 'Bangkok'
df_26.iloc[1,0] = 'Central Region'
df_26.iloc[2,0] = 'Western Region'
df_26.iloc[3,0] = 'Eastern Region'
df_26.iloc[4,0] = 'South Region'
df_26.iloc[5,0] = 'North Region'
df_26.iloc[6,0] = 'Northeast'
df_26.iloc[7,0] = 'Thailand'

# %% [markdown]
# Row -> Column

# %%
y_2563_2 = y_2563.transpose().reset_index().drop(0).rename(columns = {"index":"เดือน", 0:"กรุงเทพมหานคร", 1:"ภาคกลาง", 2:"ภาคตะวันตก", 3:"ภาคตะวันออก", 4:"ภาคใต้", 5:"ภาคเหนือ", 6:"ภาคตะวันออกเฉียงเหนือ", 7:"รวมทั้งหมด"})
y_2563_2
# Out:
#         เดือน กรุงเทพมหานคร  ภาคกลาง ภาคตะวันตก ภาคตะวันออก    ภาคใต้  \
# 1     January      31137.65   3772.3    7814.02     9400.96  18268.15
# 2    February      18810.39  2418.54    5882.98     6446.97   14878.9
# 3       March       6403.18   673.84     2552.4     3776.46    8542.8
# 4       April        434.06     1.64       2.43           0      6.12
# 5         May       1653.74    13.63       75.8       61.66      3.42
# 6        June       5189.09   497.18    2283.41     2021.09   2533.61
# 7        July       8348.66  1597.46    5173.71     4454.26   6034.11
# 8      August      14263.35  1683.32    4550.69     4545.19   5530.98
# 9   September      14106.67  1816.86    4351.14      4714.7   7042.34
# 10    October       9467.42  2638.93    6061.24     6575.64   7647.19
# 11   November      11988.41  3258.51    6652.78     9250.84   7690.29
# 12   December      11958.58  2883.07    5671.41     8123.81   7463.07
#
#     ภาคเหนือ ภาคตะวันออกเฉียงเหนือ รวมทั้งหมด
# ...

# %%
y_2564_2 = y_2564.transpose().reset_index().drop(0).rename(columns={"index":"เดือน", 0:"กรุงเทพมหานคร", 1:"ภาคกลาง", 2:"ภาคตะวันตก", 3:"ภาคตะวันออก", 4:"ภาคใต้", 5:"ภาคเหนือ", 6:"ภาคตะวันออกเฉียงเหนือ", 7:"รวมทั้งหมด"})
y_2564_2
# Out:
#         เดือน กรุงเทพมหานคร  ภาคกลาง ภาคตะวันตก ภาคตะวันออก   ภาคใต้  \
# 1     January       8447.45  1073.39    2920.88      743.11  2965.96
# 2    February       9799.71   1453.5    4393.14     1665.76  3763.53
# 3       March       9845.58   2040.9     5557.7     2380.19  6186.27
# 4       April        6164.5  1058.73    3416.72     2817.04  6231.22
# 5         May       1068.55   171.81     459.34      426.81   213.46
# 6        June        743.11   153.56     438.48      422.42   401.31
# 7        July        429.87    60.45     185.36         334   275.05
# 8      August        519.84    58.37     128.37      328.37   247.27
# 9   September       1275.61   229.75     852.46      784.43   622.27
# 10    October       1493.63   745.94    2498.72     1518.63   825.36
# 11   November       2913.82  1748.03    4468.84     5825.21  2270.48
# 12   December       9845.11  3032.82    6068.01     7062.62  5485.65
#
#     ภาคเหนือ ภาคตะวันออกเฉียงเหนือ รวมทั้งหมด
# ...

# %% [markdown]
# Plot graph

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "กรุงเทพมหานคร", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "กรุงเทพมหานคร", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Bangkok', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['กรุงเทพมหานคร']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['กรุงเทพมหานคร']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคกลาง", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคกลาง", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Central Region', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคกลาง']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคกลาง']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคตะวันตก", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคตะวันตก", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Western Region', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคตะวันตก']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคตะวันตก']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคตะวันออก", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคตะวันออก", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Eastern Region', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคตะวันออก']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคตะวันออก']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคใต้", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคใต้", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('South Region', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคใต้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคใต้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคเหนือ", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคเหนือ", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('North Region', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคเหนือ']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคเหนือ']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "ภาคตะวันออกเฉียงเหนือ", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "ภาคตะวันออกเฉียงเหนือ", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Northeast', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['ภาคตะวันออกเฉียงเหนือ']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['ภาคตะวันออกเฉียงเหนือ']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2563_2, x = "เดือน", y = "รวมทั้งหมด", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "รวมทั้งหมด", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('Thailand', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2563_2["เดือน"], y_2563_2['รวมทั้งหมด']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['รวมทั้งหมด']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = df_25, x = "ภาค", y = "รายได้", marker = "o", label = '2563', markerfacecolor = 'yellow')
sns.lineplot(data = df_26, x = "ภาค", y = "รายได้", marker = "o", label = '2564', markerfacecolor = 'red')

plt.title('2563-2564', fontsize = 25)
plt.xlabel('Region', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(df_25["ภาค"], df_25['รายได้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(df_26["ภาค"], df_26['รายได้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
df27 = df1
df28 = df2
df29 = df3
df30 = df4
df31 = df5
df32 = df6
df33 = df7
df34 = df8
df35 = df9
df36 = df10
df37 = df11
df38 = df12
df39 = df25

# %%
df_27 = df27.loc[(df27['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)','Unnamed: 21']]
df_28 = df28.loc[(df28['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)','Unnamed: 21']]
df_29 = df29.loc[(df29['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)','Unnamed: 21']]
df_30 = df30.loc[(df30['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)','Unnamed: 21']]
df_31 = df31.loc[(df31['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)','Unnamed: 21']]
df_32 = df32.loc[(df32['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)','Unnamed: 21']]
df_33 = df33.loc[(df33['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)','Unnamed: 21']]
df_34 = df34.loc[(df34['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)','Unnamed: 21']]
df_35 = df35.loc[(df35['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)','Unnamed: 21']]
df_36 = df36.loc[(df36['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)','Unnamed: 21']]
df_37 = df37.loc[(df37['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)','Unnamed: 21']]
df_38 = df38.loc[(df38['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)','Unnamed: 21']]
df_39 = df39.loc[(df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'กรุงเทพมหานคร') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคกลาง') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันตก') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออก') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคใต้') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคเหนือ') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'ภาคตะวันออกเฉียงเหนือ') | (df39['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)'] == 'รวมทั้งหมด'),['ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)','Unnamed: 21']]

# %%
df_27 = df_27.rename(columns={"รายงานเบื้องต้นเดือนมกราคม ปี 2563(P)": "ภาค", "Unnamed: 21": "January"})
df_28 = df_28.rename(columns={"รายงานเบื้องต้นเดือนกุมภาพันธ์ ปี 2563(P)": "ภาค", "Unnamed: 21": "February"})
df_29 = df_29.rename(columns={"รายงานเบื้องต้นเดือนมีนาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "March"})
df_30 = df_30.rename(columns={"รายงานเบื้องต้นเดือนเมษายน ปี 2563(P)": "ภาค", "Unnamed: 21": "April"})
df_31 = df_31.rename(columns={"รายงานเบื้องต้นเดือนพฤษภาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "May"})
df_32 = df_32.rename(columns={"รายงานเบื้องต้นเดือนมิถุนายน ปี 2563(P)": "ภาค", "Unnamed: 21": "June"})
df_33 = df_33.rename(columns={"รายงานเบื้องต้นเดือนกรกฎาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "July"})
df_34 = df_34.rename(columns={"รายงานเบื้องต้นเดือนสิงหาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "August"})
df_35 = df_35.rename(columns={"รายงานเบื้องต้นเดือนกันยายน ปี 2563(P)": "ภาค", "Unnamed: 21": "September"})
df_36 = df_36.rename(columns={"รายงานเบื้องต้นเดือนตุลาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "October"})
df_37 = df_37.rename(columns={"รายงานเบื้องต้นเดือนพฤศจิกายน ปี 2563(P)": "ภาค", "Unnamed: 21": "November"})
df_38 = df_38.rename(columns={"รายงานเบื้องต้นเดือนธันวาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "December"})
df_39 = df_39.rename(columns={"ยอดสะสมเบื้องต้นเดือนมกราคม - เดือนธันวาคม ปี 2563(P)": "ภาค", "Unnamed: 21": "รายได้"})

# %%
y_2562 = df_27.merge(df_28, how='inner').merge(df_29, how='inner').merge(df_30, how='inner').merge(df_31, how='inner').merge(df_32, how='inner').merge(df_33, how='inner').merge(df_34, how='inner').merge(df_35, how='inner').merge(df_36, how='inner').merge(df_37, how='inner').merge(df_38, how='inner')
y_2562
# Out:
#           ภาค   January  February     March     April       May      June  \
# 0  รวมทั้งหมด  94564.42  87387.18  87090.57  90057.22  85480.62  77845.11
#
#        July    August September   October  November   December
# 0  92731.27  87325.77   89652.7  92831.89  95422.45  101369.89

# %%
y_2562_2 = y_2562.transpose().reset_index().drop(0).rename(columns={"index":"เดือน", 0:"รวมทั้งหมด"})
y_2562_2
# Out:
#         เดือน รวมทั้งหมด
# 1     January   94564.42
# 2    February   87387.18
# 3       March   87090.57
# 4       April   90057.22
# 5         May   85480.62
# 6        June   77845.11
# 7        July   92731.27
# 8      August   87325.77
# 9   September    89652.7
# 10    October   92831.89
# 11   November   95422.45
# 12   December  101369.89

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = y_2562_2, x = "เดือน", y = "รวมทั้งหมด", marker = "o", label = '2562', markerfacecolor = 'yellow')
sns.lineplot(data = y_2563_2, x = "เดือน", y = "รวมทั้งหมด", marker = "o", label = '2563', markerfacecolor = 'red')
sns.lineplot(data = y_2564_2, x = "เดือน", y = "รวมทั้งหมด", marker = "o", label = '2564', markerfacecolor = 'green')

plt.title('Thailand', fontsize = 25)
plt.xlabel('Month', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(y_2562_2["เดือน"], y_2562_2['รวมทั้งหมด']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 20), textcoords='offset points')

for x,y in zip(y_2563_2["เดือน"], y_2563_2['รวมทั้งหมด']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(y_2564_2["เดือน"], y_2564_2['รวมทั้งหมด']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

# %%
df_39.iloc[0,0] = 'Bangkok'
df_39.iloc[1,0] = 'Central Region'
df_39.iloc[2,0] = 'Western Region'
df_39.iloc[3,0] = 'Eastern Region'
df_39.iloc[4,0] = 'South Region'
df_39.iloc[5,0] = 'North Region'
df_39.iloc[6,0] = 'Northeast'
df_39.iloc[7,0] = 'Thailand'

# %%
fig, ax = plt.subplots(figsize=(20, 10))

sns.lineplot(data = df_39, x = "ภาค", y = "รายได้", marker = "o", label = '2562', markerfacecolor = 'yellow')
sns.lineplot(data = df_25, x = "ภาค", y = "รายได้", marker = "o", label = '2563', markerfacecolor = 'red')
sns.lineplot(data = df_26, x = "ภาค", y = "รายได้", marker = "o", label = '2564', markerfacecolor = 'green')

plt.title('2562-2564', fontsize = 25)
plt.xlabel('Region', fontsize = 25)
plt.ylabel('Income from Thai tourists(million bath)', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.rc('legend',fontsize=15)

for x,y in zip(df_39["ภาค"], df_39['รายได้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 10), textcoords='offset points')

for x,y in zip(df_25["ภาค"], df_25['รายได้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(0, 7), textcoords='offset points')
    
for x,y in zip(df_26["ภาค"], df_26['รายได้']):
    label = "{:,.0f}".format(y)
    plt.annotate(label, (x,y), ha='center', fontsize=15, xytext=(30, 0), textcoords='offset points')
